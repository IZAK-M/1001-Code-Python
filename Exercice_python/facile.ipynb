# %% [markdown]
# #### Exercice 1
# Ecrire un programme en langage Python qui demande à l'utilisateur de saisir son nom et de lui afficher son nom avec un message de bienvenue !

# %%
nom = input("Merci de saisir votre nom prénom : ")
print(f"Bienvenue {nom} !")
# Out:
# Bienvenue izak mohamed !

# %% [markdown]
# #### Exercice 2
# Ecrire un programme en Python qui demande à l'utilisateur de saisir deux nombres a et b et de lui afficher leur somme : a + b

# %%
a = float(input("Tapez la valeur du nombre a : "))
b = float(input("Tapez la valeur du nombre b : "))

print(f"Somme de a + b = {a + b}")
# Out:
# Somme de a + b = 10.0

# %% [markdown]
# #### Exercice 3
# Ecrire un programme en Python qui demande à l'utilisateur de saisir deux nombres a et b et de lui afficher leur maximum.

# %%
# Sans utilisation de max()
a = float(input("Tapez la valeur du nombre a : "))
b = float(input("Tapez la valeur du nombre b : "))

if a > b:
    print(f"Valeur maximum : {a}")
else:
    print(f"Valeur maximum {b}")
# Out:
# Valeur maximum 12.0

# %%
# Avec utilisation de max()
a = float(input("Tapez la valeur du nombre a : "))
b = float(input("Tapez la valeur du nombre b : "))

print(f"Le maximum est {max(a, b)}")
# Out:
# Le maximum est 7.0

# %% [markdown]
# #### Exercice 4
# Ecrire un programme en langage Python qui affiche les 100 premiers nombres entiers

# %%
for i in range(1, 101):
    print(i)

# %% [markdown]
# #### Exercice 5
# Ecrire un programme en langage Python qui demande à l'utilisateur de saisir son nombre entier et de lui afficher si ce nombre est pair ou impair.

# %%
nombre = int(input("Entrez un nombre entier : "))

if nombre % 2 == 0:
    print(f"{nombre} est un nombre pair.")
else:
    print(f"{nombre} est un nombre impair.")
# Out:
# 10 est pair

# %% [markdown]
# #### Exercice 6
# Ecrire un programme en langage Python qui demande à l'utilisateur de saisir son âge et de lui afficher le message « vous êtes Majeur ! »
# si l’âge tapé est supérieur ou égale à 18 et le message « vous êtes mineur ! » si l’âge tapé est inférieur à 18

# %%
age = int(input("Tapez votre age : "))

status = "Vous êtes Majeur !" if age >= 18 else "Vous êtes Mineur!"

print(status)
# Out:
# Vous êtes Majeur !

# %% [markdown]
# #### Exercice 7
# Ecrire un programme en Python qui demande à l'utilisateur de saisir 3 nombre x, y et z et de lui afficher leur maximum

# %%
# Avec une liste :
x = float(input("Tapez la valeur du nombre x : "))
y = float(input("Tapez la valeur du nombre y : "))
z = float(input("Tapez la valeur du nombre z : "))

list_nombre = [x,y,z]

print(f"Le maximum est : {max(list_nombre)}")
# Out:
# Le maximum est : 12.0

# %%
# Avec un dictionnaire :
x = float(input("Tapez la valeur du nombre x : "))
y = float(input("Tapez la valeur du nombre y : "))
z = float(input("Tapez la valeur du nombre z : "))

if x > y and x > z:
    print(f"Le maximum est : {x}")
elif y > x and y > z:
    print(f"Le maximum est : {y}")
else:
    print(f"Le maximum est : {z}")
# Out:
# Le maximum est : 12.0

# %% [markdown]
# #### Exercice 8
# Ecrire un programme en Python qui demande à l'utilisateur de saisir un nombre entier n et de lui afficher la valeur de la somme 1 + 2 + … + n =

# %%
n = int(input("Tapez le valeur nombre n : "))

somme = 0

for i in range (1, n+1):
    somme += i

print(f"La somme 1+2+...+n = {somme}")
# Out:
# La somme 1+2+...+n = 6

# %% [markdown]
# #### Exercice 9
# Ecrire un programme en Python qui demande à l'utilisateur de saisir un nombre entier n et de lui afficher n ! (Factoriel)

# %%
n = int(input("Tapez la valeur du nombre n : "))

factoriel = 1

for i in range (1, n+1):
    factoriel *= i

print(f"Le {n}! = {factoriel}")
# Out:
# Le 7! = 5040

# %%
# Fonction pour calculer le factoriel d'un nombre
def factoriel(n):
    if n == 0:
        return 1
    else:
        return n * factoriel(n-1)
    
# --- Utilisation de la fonction factoriel ---

n = int(input("Entrez un nombre entier : "))
 
# Calculer le factoriel de n en appelant la fonction factoriel
resultat = factoriel(n)
 
# Afficher le résultat
print(f"Le {n}! = {resultat}")
# Out:
# Le 7! = 5040

# %% [markdown]
# #### Exercice 10
# Ecrire un programme en Python qui demande à l’utilisateur de saisir le rayon d'un cercle et de lui renvoyer la surface et le périmètre.

# %%
from math import pi

rayon = float(input("Saisissez la valeur du rayon r : "))

surface =  round(pi * (rayon**2), 2)
perimetre = round(2 * pi * rayon, 2)

print(f"La surface du cercle de rayons r, {rayon}, est S = {surface}" )
print(f"Le périmètre du cercle de rayons r, {rayon}, est P = {perimetre}")
# Out:
# La surface du cercle de rayons r, 5.4, est S = 91.61
# Le périmètre du cercle de rayons r, 5.4, est P = 33.93

# %% [markdown]
# #### Exercice 11
# Ecrire un programme en Python qui demande à l’utilisateur de saisir un nombre entier n et de lui afficher tous les diviseurs de ce nombre.

# %%
n = int(input("Saisissez la valeur du nombre n : "))

for i in range (1, n+1):
    if n % i == 0:
        print(f"Le nombre {i}, est un diviseur de {n}")
# Out:
# Le nombre 1, est un diviseur de 5
# Le nombre 5, est un diviseur de 5

# %% [markdown]
# #### Exercice 12
# 1) - Ecrire un programme en Python qui demande à l’utilisateur de saisir un nombre entier n et de lui afficher la table de multiplication de ce nombre.
# 2) - Améliorez le programme afin qu’il affiche les tables de multiplications de tous les nombres compris entre 1 et 9

# %%
n = int(input("Saisissez la valeur du nombre n "))

for i in range (1, 11):
    print(f"{i} x {n} = {i*n}")
# Out:
# 1 x 2 = 2
# 2 x 2 = 4
# 3 x 2 = 6
# 4 x 2 = 8
# 5 x 2 = 10
# 6 x 2 = 12
# 7 x 2 = 14
# 8 x 2 = 16
# 9 x 2 = 18
# 10 x 2 = 20

# %% [markdown]
# #### Exercice 13
# Ecrire un programme en langage Python qui demande à l'utilisateur de saisir deux nombres entiers a et b et de lui afficher le quotient et le reste de la division euclidienne de a par b

# %%
a = int(input("Entrez le premier nombre entier : "))
b = int(input("Entrez le deuxième nombre entier : "))

# Calcul du quotient et le reste de la division euclidienne
quotient = a // b
reste = a % b
 
# Afficher le résultat
print(f"Le quotient de la division euclidienne de {a} par {b} est : {quotient}")
print(f"Le reste de la division euclidienne de {a} par{b} est : {reste}")
# Out:
# Le quotient de la division euclidienne de 15 par 7 est : 2
# Le reste de la division euclidienne de 15 par7 est : 1

# %% [markdown]
# #### Exercice 14
# Ecrire un programme en langage Python qui demande à l'utilisateur de saisir un nombre entier n et de lui afficher si ce nombre est carré parfait ou non

# %%
n = int(input("Veuillez saisir un nombre entier: "))
 
i = 0
 
while i * i < n:
    i += 1
 
# Vérifier si le carré de i est égal à n
if i * i == n:
    print(n,  " : est un carré parfait.")
else:
    print(n, " : n'est pas un carré parfait.")
# Out:
# 16  : est un carré parfait.

# %% [markdown]
# #### Exercice 15
# Ecrire un programme en langage Python qui demande à l'utilisateur de saisir un nombre entier n et de lui afficher si ce nombre est premier ou non.

# %%
n = int(input("Tapez la valeur de n :  "))

nombre_diviseur = 0
for i in range(1, n+1):
    if(n%i == 0):
        nombre_diviseur += 1
 
if( nombre_diviseur == 2):
    print(f"{n} est un nombre premier")
else:
    print(f"{n} n'est pas un nombre premier")
# Out:
# 15 n'est pas un nombre premier

# %% [markdown]
# #### Exercice 16
# Ecrire un programme en langage Python qui permet de parcourir et afficher les caractères d’une variable du type chaine de caractères. Exemple pour s = « Python » , le programme affiche les caractères :
# P
# y
# t
# h
# o
# n

# %%
s = input("Saisissez la valeur de s : ")
 
for c in s:
    print(c)
# Out:
# P
# y
# t
# h
# o
# n

# %% [markdown]
# #### Exercice 17
# Ecrire un programme en Python permettant d’afficher pour une chaine de caractères donnée, le nombre d’occurrences de chaque caractère dans la chaine. Exemple pour la chaine de caractère s = « Python.org » le programme doit afficher :
#
# Le caractère : " P " figure 1 fois dans la chaine s
#
# Le caractère : " y " figure 1 fois dans la chaine s
#
# Le caractère : " t " figure 1 fois dans la chaine s
#
# Le caractère : " h " figure 1 fois dans la chaine s
#
# Le caractère : " o " figure 2 fois dans la chaine s
#
# Le caractère : " n " figure 1 fois dans la chaine s
#
# Le caractère : " . " figure 1 fois dans la chaine s
#
# Le caractère : " r " figure 1 fois dans la chaine s
#
# Le caractère : " g " figure 1 fois dans la chaine s

# %%
s = input("Saisissez votre valeur de s : ")

for e in set(s):
    if e == " ":
        continue

    count = s.count(e)

    print(f"Le caractère : \"{e}\" figure {count} fois dans la chaine {s}")
# Out:
# Le caractère : "h" figure 1 fois dans la chaine Python.org
# Le caractère : "o" figure 2 fois dans la chaine Python.org
# Le caractère : "y" figure 1 fois dans la chaine Python.org
# Le caractère : "r" figure 1 fois dans la chaine Python.org
# Le caractère : "P" figure 1 fois dans la chaine Python.org
# Le caractère : "n" figure 1 fois dans la chaine Python.org
# Le caractère : "." figure 1 fois dans la chaine Python.org
# Le caractère : "g" figure 1 fois dans la chaine Python.org
# Le caractère : "t" figure 1 fois dans la chaine Python.org

# %% [markdown]
# #### Exercice 18
# Ecrire un programme en Python qui demande à l’utilisateur de saisir une chaine de caractère s et de lui renvoyer un message indiquant si la chaine contient la lettre 'a' tout en indiquant sa position sur la chaine. Exemple si l’utilisateur tape la chaine s = ‘langage’ le programme lui renvoie :
# La lettre 'a' se trouve à la position : 1
# La lettre 'a' se trouve à la position : 4

# %%
s = input("Saisissez la valeur de s : ")

has_a = False

for i, e in enumerate(s):
    if e == "a":
        print(f"La lettre 'a' se trouve à la position : {i}")
        has_a = True

if not has_a:
    print(f"La chaine {s} ne contient pas la lettre 'a' ")
# Out:
# La lettre 'a' se trouve à la position : 1
# La lettre 'a' se trouve à la position : 3

# %%
s = input("Saisissez la valeur de s : ")

n = len(s)

has_a = False

for i in range(0,n):
    if s[i] == 'a':
        print(f"La lettre 'a' se trouve à la position : {i}")
        has_a = True

if not has_a:
    print(f"La chaine {s} ne contient pas la lettre 'a' ")
# Out:
# La lettre 'a' se trouve à la position : 1
# La lettre 'a' se trouve à la position : 3
